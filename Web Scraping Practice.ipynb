# %%
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:73.0) Gecko/20100101 Firefox/73.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Cache-Control': 'max-age=0',
}

params = (
    ('sid', 'g9b,0yh,jhz'),
    ('p[]', ['facets.ideal_for%5B%5D=Men+%26+Women', 'facets.ideal_for%5B%5D=Men', 'facets.serviceability[]=true']),
    ('otracker', ['categorytree', 'nmenu_sub_Men_0_Perfumes']),
)

response = requests.get('https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b,0yh,jhz&p[]=facets.ideal_for%255B%255D%3DMen%2B%2526%2BWomen&p[]=facets.ideal_for%255B%255D%3DMen&p[]=facets.serviceability%5B%5D%3Dtrue&otracker=categorytree&otracker=nmenu_sub_Men_0_Perfumes', headers=headers, cookies=cookies)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.51d146.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %%
soup=BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.51d146.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
main_box=soup.find_all("div",{"class":"_1UoZlx"})

# %%
len(main_box)
# Out:
# 0

# %%
box=main_box[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-8fc70e4b6b96> in <module>
# ----> 1 box=main_box[0]
#
# IndexError: list index out of range

# %% [markdown]
# ## Parsing the HTML using Beautiful Soup.

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text,'html.parser')

# %%
results=soup.find_all('meta',attrs={'property':'og:description'})

# %%
len(results)
# Out:
# 1

# %%
results[0:3]
# Out:
# [<meta content="Perfumes at upto 30% OFF: Buy Best Perfumes for Men and Women Online at India's Best Online Shopping Store. Widest Range with Attractive Prices and Best Discounts. Find widest range of Perfumes on Flipkart.com" name="Description" property="og:description">
#  <link href="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" rel="canonical"/>
#  <link href="android-app://com.flipkart.android/flipkart/de_sp_seg_--_g9b%252F0yh%252Fjhz" rel="alternate"/>
#  <meta content="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" name="og_url" property="og:url">
#  <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01">
#  <!--[if IE 9 ]>
#  	<script nonce="14788905447772778201">
#  		window.browserVersion = 'IE9';
#  		document.documentElement.className += ' ie9';
#  	</script>
#  	<![endif]-->
#  <!--[if !IE]><!-->
#  <script nonce="14788905447772778201">
#  		if (/*@cc_on!@*/false) {
# ...

# %%
results[-1]
# Out:
# <meta content="Perfumes at upto 30% OFF: Buy Best Perfumes for Men and Women Online at India's Best Online Shopping Store. Widest Range with Attractive Prices and Best Discounts. Find widest range of Perfumes on Flipkart.com" name="Description" property="og:description">
# <link href="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" rel="canonical"/>
# <link href="android-app://com.flipkart.android/flipkart/de_sp_seg_--_g9b%252F0yh%252Fjhz" rel="alternate"/>
# <meta content="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" name="og_url" property="og:url">
# <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01">
# <!--[if IE 9 ]>
# 	<script nonce="14788905447772778201">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
# <!--[if !IE]><!-->
# <script nonce="14788905447772778201">
# 		if (/*@cc_on!@*/false) {
# ...

# %%
first_result=results[0]
first_result
# Out:
# <meta content="Perfumes at upto 30% OFF: Buy Best Perfumes for Men and Women Online at India's Best Online Shopping Store. Widest Range with Attractive Prices and Best Discounts. Find widest range of Perfumes on Flipkart.com" name="Description" property="og:description">
# <link href="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" rel="canonical"/>
# <link href="android-app://com.flipkart.android/flipkart/de_sp_seg_--_g9b%252F0yh%252Fjhz" rel="alternate"/>
# <meta content="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" name="og_url" property="og:url">
# <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01">
# <!--[if IE 9 ]>
# 	<script nonce="14788905447772778201">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
# <!--[if !IE]><!-->
# <script nonce="14788905447772778201">
# 		if (/*@cc_on!@*/false) {
# ...

# %%
first_result.find('meta').text[0:-1]
# Out:
# '\n\n\n\n\n\t\tif (/*@cc_on!@*/false) {\n\t\t\twindow.browserVersion = \'IE10\';\n\t\t\tdocument.documentElement.className += \' ie10\';\n\t\t}\n\t\n\n\n        {"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.flipkart.com/ustraa-cologne-men-after-dark-perfume-100-ml/p/itm241943b6ef58d?pid=PERFHPHP4EJHWS46&lid=LSTPERFHPHP4EJHWS46TNIMJW&marketplace=FLIPKART","name":"Ustraa Cologne for Men- After Dark Perfume  -  100 ml"},{"@type":"ListItem","position":2,"url":"https://www.flipkart.com/fastrack-perfumesolo-eau-de-parfum-100-ml/p/itm0b230318ebd8b?pid=PERFMGHR6DZGHAWE&lid=LSTPERFMGHR6DZGHAWEBW1J5B&marketplace=FLIPKART","name":"Fastrack Perfume�solo Eau de Parfum  -  100 ml"},{"@type":"ListItem","position":3,"url":"https://www.flipkart.com/fogg-scent-impressio-eau-de-parfum-100-ml/p/itmf96jec24hfqv6?pid=PEREGESFPY3H4AFQ&lid=LSTPEREGESFPY3H4AFQKVT0WR&marketplace=FLIPKART","name":"Fogg Scent Impressio Eau de Parfum  - 
# ...

# %%
first_result.contents[1]
# Out:
# <link href="https://www.flipkart.com/beauty-and-grooming/fragrances/perfume/pr?sid=g9b%2C0yh%2Cjhz" rel="canonical"/>

# %%
first_result.contents[1][1:-2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-53e6edfa91b3> in <module>
# ----> 1 first_result.contents[1][1:-2]
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#     969         """tag[key] returns the value of the 'key' attribute for the tag,
#     970         and throws an exception if it's not there."""
# --> 971         return self.attrs[key]
#     972
#     973     def __iter__(self):
#
# TypeError: unhashable type: 'slice'

# %%
import pandas as pd

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...
